# %%
import torch
import time
import random 
import models
import numpy as np
import pandas as pd
import torch.nn as nn
from transformers import PreTrainedTokenizerFast
from utils import EarlyStopping
from dataset import train_dataloader, val_dataloader, train_dataset, val_dataset
from torch import optim
from tqdm import tqdm

random.seed(42)
# Out:
# Ignored unknown kwarg option direction

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
tokenizer = PreTrainedTokenizerFast(tokenizer_file = '../Input/BERiT_tokenizer.json', 
                                    pad_token = "<pad>", 
                                    bos_token = "<s>", 
                                    eos_token = "</s>", 
                                    mask_token = "<mask>")

# %%
model = models.model.to(device)

# %%
total_trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f"{total_trainable_params:,} total trainable parameters.")
# Out:
# 1,336,576 total trainable parameters.

# %%
n_epochs = 50

criterion = nn.CrossEntropyLoss(label_smoothing = .2, ignore_index = tokenizer.pad_token_id) #correct?

optimizer = torch.optim.Adam(model.parameters(), lr = .0005)

early_stopping = EarlyStopping(patience = 10)

# %%
def fit(model, train_iterator, train_dataset, optimizer, criterion):
    print('Training')
    model.train()
    train_running_loss = 0.0
    counter = 0
    
    prog_bar = tqdm(enumerate(train_iterator), total = int(len(train_dataset) / train_iterator.batch_size))
    
    for idx, batch in prog_bar:
        counter += 1
        input_ids, attn_mask, labels = batch['input_ids'].to(device), batch['attention_mask'].to(torch.bool).to(device), batch['labels'].to(device)        
        optimizer.zero_grad()
        output = model(input_ids, attn_mask)
        loss = criterion(output, labels)
        train_running_loss += loss.item()
        loss.backward()
        optimizer.step()

    train_loss = train_running_loss / counter
    
    return train_loss

# %%
def validate(model, val_iterator, val_dataset, criterion):
    print('Validating')
    model.eval()
    val_running_loss = 0.0
    counter = 0
    
    prog_bar = tqdm(enumerate(val_iterator), total = int(len(val_dataset) / val_iterator.batch_size))

    with torch.no_grad():
        
    
        for idx, batch in prog_bar:

            counter += 1
            input_ids, attn_mask, labels = batch['input_ids'].to(device), batch['attention_mask'].to(torch.bool).to(device), batch['labels'].to(device)
            output = model(input_ids, attn_mask)
            loss = criterion(output, labels)
            val_running_loss += loss.item()
    
    val_loss = val_running_loss / counter

    return val_loss

# %%
train_losses = []
val_losses = []

start = time.time()
for epoch in range(n_epochs):

    print(f"Epoch {epoch + 1}/{n_epochs}")    
    train_epoch_loss = fit(model, train_dataloader, train_dataset, optimizer, criterion)
    train_losses.append(train_epoch_loss)

    val_epoch_loss = validate(model, val_dataloader, val_dataset, optimizer, criterion)
    val_losses.append(val_epoch_loss)

    early_stopping(val_epoch_loss)

    if early_stopping.early_stop:
        break

    print(f"Training Loss: {train_epoch_loss:.5} \n Validation Loss: {val_epoch_loss:.5}")    
end = time.time()

print(f"Training Titme: {(end - start) / 60: .3f} minutes")
# Out:
# Epoch 1/50
# Training
#   0%|                                                  | 0/1835 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [15], in <module>
#       5 for epoch in range(n_epochs):
#       7     print(f"Epoch {epoch + 1}/{n_epochs}")
# ----> 8     train_epoch_loss = fit(model, train_dataloader, train_dataset, optimizer, criterion)
#       9     train_losses.append(train_epoch_loss)
#      11     val_epoch_loss = validate(model, val_dataloader, val_dataset, optimizer, criterion)
#
# Input In [11], in fit(model, train_iterator, train_dataset, optimizer, criterion)
#      11 input_ids, attn_mask, labels = batch['input_ids'].to(device), batch['attention_mask'].to(torch.bool).to(device), batch['labels'].to(device)
#      12 optimizer.zero_grad()
# ---> 13 output = model(input_ids, attn_mask)
#      14 loss = criterion(output, labels)
#      15 train_running_loss += loss.item()
#
# File ~/miniforge3/envs/Springboard/lib/python3.9/site-packages/torch/nn/modules/module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Desktop/BERiT/BERiT/src/utils.py:72, in Encoder.forward(self, input_ids, attention_mask)
#      68 pos = torch.arange(0, input_len).unsqueeze(0).repeat(batch_size, 1)
#      70 input_ids = self.dropout(self.norm((self.tok_embed(input_ids) * self.scale) + self.pos_embed(pos)))
# ---> 72 encoding = self.encoder(input_ids, attention_mask)
#      74 return encoding
#
# File ~/miniforge3/envs/Springboard/lib/python3.9/site-packages/torch/nn/modules/module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniforge3/envs/Springboard/lib/python3.9/site-packages/torch/nn/modules/transformer.py:339, in TransformerEncoderLayer.forward(self, src, src_mask, src_key_padding_mask)
#     337     x = x + self._ff_block(self.norm2(x))
#     338 else:
# --> 339     x = self.norm1(x + self._sa_block(x, src_mask, src_key_padding_mask))
#     340     x = self.norm2(x + self._ff_block(x))
#     342 return x
#
# File ~/miniforge3/envs/Springboard/lib/python3.9/site-packages/torch/nn/modules/transformer.py:347, in TransformerEncoderLayer._sa_block(self, x, attn_mask, key_padding_mask)
#     345 def _sa_block(self, x: Tensor,
#     346               attn_mask: Optional[Tensor], key_padding_mask: Optional[Tensor]) -> Tensor:
# --> 347     x = self.self_attn(x, x, x,
#     348                        attn_mask=attn_mask,
#     349                        key_padding_mask=key_padding_mask,
#     350                        need_weights=False)[0]
#     351     return self.dropout1(x)
#
# File ~/miniforge3/envs/Springboard/lib/python3.9/site-packages/torch/nn/modules/module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniforge3/envs/Springboard/lib/python3.9/site-packages/torch/nn/modules/activation.py:1003, in MultiheadAttention.forward(self, query, key, value, key_padding_mask, need_weights, attn_mask)
#     992     attn_output, attn_output_weights = F.multi_head_attention_forward(
#     993         query, key, value, self.embed_dim, self.num_heads,
#     994         self.in_proj_weight, self.in_proj_bias,
#    (...)
#    1000         q_proj_weight=self.q_proj_weight, k_proj_weight=self.k_proj_weight,
#    1001         v_proj_weight=self.v_proj_weight)
#    1002 else:
# -> 1003     attn_output, attn_output_weights = F.multi_head_attention_forward(
#    1004         query, key, value, self.embed_dim, self.num_heads,
#    1005         self.in_proj_weight, self.in_proj_bias,
#    1006         self.bias_k, self.bias_v, self.add_zero_attn,
#    1007         self.dropout, self.out_proj.weight, self.out_proj.bias,
#    1008         training=self.training,
#    1009         key_padding_mask=key_padding_mask, need_weights=need_weights,
#    1010         attn_mask=attn_mask)
#    1011 if self.batch_first:
#    1012     return attn_output.transpose(1, 0), attn_output_weights
#
# File ~/miniforge3/envs/Springboard/lib/python3.9/site-packages/torch/nn/functional.py:5011, in multi_head_attention_forward(query, key, value, embed_dim_to_check, num_heads, in_proj_weight, in_proj_bias, bias_k, bias_v, add_zero_attn, dropout_p, out_proj_weight, out_proj_bias, training, key_padding_mask, need_weights, attn_mask, use_separate_proj_weight, q_proj_weight, k_proj_weight, v_proj_weight, static_k, static_v)
#    5009     correct_2d_size = (tgt_len, src_len)
#    5010     if attn_mask.shape != correct_2d_size:
# -> 5011         raise RuntimeError(f"The shape of the 2D attn_mask is {attn_mask.shape}, but should be {correct_2d_size}.")
#    5012     attn_mask = attn_mask.unsqueeze(0)
#    5013 elif attn_mask.dim() == 3:
#
# RuntimeError: The shape of the 2D attn_mask is torch.Size([10, 100]), but should be (10, 10).
